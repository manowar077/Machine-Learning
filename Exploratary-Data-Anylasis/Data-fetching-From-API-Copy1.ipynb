# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=58e179a98009cdf7e36b71e12d841ad4&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/caBIySpwuFi2i7ynvHIlnxJLOdN.jpg',
#    'genre_ids': [16, 28, 12, 878],
#    'id': 1560520,
#    'title': 'Batman: Knightfall Part 1: Knightfall',
#    'original_language': 'en',
#    'original_title': 'Batman: Knightfall Part 1: Knightfall',
#    'overview': 'Arkham Asylum has been destroyed, and all its inmates have been unleashed upon Gotham City. As Batman races to round up some of his greatest enemies, he is pushed to his physical and mental limits and into a final confrontation with a new threat: the man called Bane!',
#    'popularity': 83.7608,
#    'poster_path': '/360qdtu2hLnqMu8SVHMywn420w1.jpg',
#    'release_date': '2026-06-23',
#    'softcore': False,
#    'video': False,
#    'vote_average': 9.18,
#    'vote_count': 314},
#   {'adult': False,
#    'backdrop_path': '/ezbrL1dMymKQZw7mDEWa2ZTzN7d.jpg',
#    'genre_ids': [16, 12, 14, 28],
#    'id': 980431,
#    'title': 'Avatar Aang: The Last Airbender',
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/caBIySpwuFi2i7ynvHIlnxJLOdN.jpg',
#   'genre_ids': [16, 28, 12, 878],
#   'id': 1560520,
#   'title': 'Batman: Knightfall Part 1: Knightfall',
#   'original_language': 'en',
#   'original_title': 'Batman: Knightfall Part 1: Knightfall',
#   'overview': 'Arkham Asylum has been destroyed, and all its inmates have been unleashed upon Gotham City. As Batman races to round up some of his greatest enemies, he is pushed to his physical and mental limits and into a final confrontation with a new threat: the man called Bane!',
#   'popularity': 83.7608,
#   'poster_path': '/360qdtu2hLnqMu8SVHMywn420w1.jpg',
#   'release_date': '2026-06-23',
#   'softcore': False,
#   'video': False,
#   'vote_average': 9.18,
#   'vote_count': 314},
#  {'adult': False,
#   'backdrop_path': '/ezbrL1dMymKQZw7mDEWa2ZTzN7d.jpg',
#   'genre_ids': [16, 12, 14, 28],
#   'id': 980431,
#   'title': 'Avatar Aang: The Last Airbender',
#   'original_language': 'en',
# ...

# %%
df_temp=pd.DataFrame(response.json()['results'])[['id','title','popularity','vote_average']]

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=58e179a98009cdf7e36b71e12d841ad4&language=en-US&page={}'.format(i))
    df_temp=pd.DataFrame(response.json()['results'])[['id','title','popularity','vote_average']]
    df = pd.concat([df, df_temp], ignore_index=True)

# %%
df
# Out:
#            id                                  title  popularity  vote_average
# 0     1560520  Batman: Knightfall Part 1: Knightfall     83.7608         9.180
# 1      980431        Avatar Aang: The Last Airbender     90.3732         9.100
# 2     1007757                                Swapped     40.5371         8.869
# 3     1632181                    Accidental Partners     18.0217         8.850
# 4     1621552                        Facing El Chapo    113.2789         8.800
# ...       ...                                    ...         ...           ...
# 3215    19673                             Sexmission      4.4984         7.200
# 3216    18947                   The Boat That Rocked      5.4419         7.223
# 3217    12622                            Violent Cop      3.7954         7.230
# 3218    11176                       The Muppet Movie      6.7341         7.223
# 3219    10528                        Sherlock Holmes     12.5884         7.222
#
# [3220 rows x 4 columns]

# %%
df.shape
# Out:
# (3220, 4)

# %%
#coverrt into csv
df.to_csv('movies.csv')

# %%
# Out:
#            id                                  title  popularity  vote_average
# 0     1560520  Batman: Knightfall Part 1: Knightfall     83.7608         9.180
# 1      980431        Avatar Aang: The Last Airbender     90.3732         9.100
# 2     1007757                                Swapped     40.5371         8.869
# 3     1632181                    Accidental Partners     18.0217         8.850
# 4     1621552                        Facing El Chapo    113.2789         8.800
# ...       ...                                    ...         ...           ...
# 3215    19673                             Sexmission      4.4984         7.200
# 3216    18947                   The Boat That Rocked      5.4419         7.223
# 3217    12622                            Violent Cop      3.7954         7.230
# 3218    11176                       The Muppet Movie      6.7341         7.223
# 3219    10528                        Sherlock Holmes     12.5884         7.222
#
# [3220 rows x 4 columns]
